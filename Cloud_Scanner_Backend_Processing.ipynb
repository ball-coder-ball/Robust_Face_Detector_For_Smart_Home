# %%
# !pip install -q pyngrok nest_asyncio uvicorn fastapi deepface line-bot-sdk
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.3/128.3 kB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 818.9/818.9 kB 35.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.6/165.6 kB 16.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 11.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 73.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 50.1 MB/s eta 0:00:00

# %%
# # ตัวอย่าง Code สำหรับรันใน Colab
# import nest_asyncio
# from pyngrok import ngrok
# import uvicorn
# from backend_main import app # import app จากไฟล์ backend_main.py ของคุณ

# # ใส่ Ngrok Token ของคุณ (สมัครฟรีที่ dashboard.ngrok.com)
# ngrok.set_auth_token("35HRFySeHKxSBkuFZ48n0tT6sZl_CoVKLmVZ1o1CuKUwoSje")

# # เปิด Tunnel
# ngrok_tunnel = ngrok.connect(8000)
# print('Public URL:', ngrok_tunnel.public_url)

# # รัน Server
# nest_asyncio.apply()
# uvicorn.run(app, port=8000) #uvicorn.run() จะเรียนก asyncio.run() ซ้ำซ้อน ซึ่งจะชนกับ Loop ของ Colab ทำให้เกิด Error

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import uvicorn
import nest_asyncio
from pyngrok import ngrok
from backend_main import app

# 1. Apply Patch (เพื่อให้ Loop ทำงานซ้อนกันได้ในบางจังหวะ)
nest_asyncio.apply()

# 2. Setup Ngrok (ใส่ Token ของคุณตรงนี้ถ้ายังไม่ได้ใส่)
ngrok.set_auth_token("35HRFySeHKxSBkuFZ48n0tT6sZl_CoVKLmVZ1o1CuKUwoSje")

# 3. เปิด Tunnel
# ปิด Tunnel เก่าก่อน (ถ้ามี) เพื่อไม่ให้ port ชน
ngrok.kill()
ngrok_tunnel = ngrok.connect(8000)
print('Public URL:', ngrok_tunnel.public_url)

# 4. รัน Server แบบ Async (วิธีที่ถูกต้องสำหรับ Colab)
config = uvicorn.Config(app, port=8000)
server = uvicorn.Server(config)
await server.serve()
# Out:
# Public URL: https://alma-unvirulent-lanita.ngrok-free.dev
# INFO:     Started server process [592]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     58.181.180.139:0 - "OPTIONS /api/v1/check-face-existence HTTP/1.1" 200 OK
# INFO:     58.181.180.139:0 - "POST /api/v1/check-face-existence HTTP/1.1" 200 OK
# 🔍 Prediction Score: 0.9652 => ✅ Real
# INFO:     58.181.180.139:0 - "POST /api/v1/spoof-check HTTP/1.1" 200 OK
# INFO:     58.181.180.139:0 - "OPTIONS /api/v1/request-permission HTTP/1.1" 200 OK
# INFO:     58.181.180.139:0 - "POST /api/v1/request-permission HTTP/1.1" 200 OK
# INFO:     147.92.150.198:0 - "POST /webhook HTTP/1.1" 200 OK
# INFO:     147.92.150.198:0 - "POST /webhook HTTP/1.1" 200 OK
